# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
url_tmpl = 'https://finance.naver.com/item/main.nhn?code=%s'
url = url_tmpl % ('005930')

item_info = requests.get(url).text
soup = BeautifulSoup(item_info, 'html.parser')
finance_info = soup.select('div.section.cop_analysis div.sub_section')[0]

th_data = [item.get_text().strip() for item in finance_info.select('thead th')]
annual_date = th_data[3:7]
quarter_date = th_data[7:13]

finance_index = [item.get_text().strip() for item in finance_info.select('th.h_th2')][3:]

finance_data = [item.get_text().strip() for item in finance_info.select('td')]
finance_data = np.array(finance_data)
finance_data.resize(len(finance_index), 10)

finance_date = annual_date + quarter_date

finance = pd.DataFrame(data=finance_data[0:,0:], index=finance_index, columns=finance_date)

# %%
finance
# Out:
#              2017.12    2018.12    2019.12 2020.12(E)    2019.06    2019.09  \
# 매출액        2,395,754  2,437,714  2,304,009  2,388,064    561,271    620,035
# 영업이익         536,450    588,867    277,685    372,393     65,971     77,779
# 당기순이익        421,867    443,449    217,389    279,829     51,806     62,877
# 영업이익률          22.39      24.16      12.05      15.59      11.75      12.54
# 순이익률           17.61      18.19       9.44      11.72       9.23      10.14
# ROE(지배주주)      21.01      19.63       8.69      10.48      13.23      10.05
# 부채비율           40.68      36.97      34.12                 33.05      34.14
# 당좌비율          181.61     204.12     233.57                230.74     235.80
# 유보율        24,536.12  27,531.92  28,856.02             28,129.35  28,541.64
# EPS(원)         5,421      6,024      3,166      4,083        746        899
# PER(배)          9.40       6.42      17.63      14.77      10.48      13.73
# BPS(원)        30,427     35,342     37,528     40,416     36,789     37,600
# PBR(배)          1.67       1.09       1.49       1.49       1.28       1.30
# 주당배당금(원)         850      1,416      1,416      1,576
# 시가배당률(%)        1.67       3.66       2.54
# 배당성향(%)        14.09      21.92      44.73
#
#              2019.12    2020.03    2020.06 2020.09(E)
# 매출액          598,848    553,252    529,661    639,082
# 영업이익          71,603     64,473     81,463    102,603
# 당기순이익         52,270     48,849     55,551     77,786
# 영업이익률          11.96      11.65      15.38      16.05
# 순이익률            8.73       8.83      10.49      12.17
# ROE(지배주주)       8.69       8.45       8.49
# 부채비율           34.12      34.19      32.67
# 당좌비율          233.57     237.80     250.04
# 유보율        28,856.02  29,134.12  29,477.97
# EPS(원)           770        720        808      1,224
# PER(배)         17.63      15.24      16.52      47.56
# BPS(원)        37,528     38,053     38,534
# PBR(배)          1.49       1.25       1.37
# 주당배당금(원)
# 시가배당률(%)
# 배당성향(%)
